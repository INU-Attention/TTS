# %% [markdown]
# # 학습코드

# %%
# !pip install wandb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wandb
#   Downloading wandb-0.16.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (5.9.8)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.40.3-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (69.0.3)
# Collecting appdirs>=1.4.3 (from wandb)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from wandb) (4.23.4)
# Requirement already satisfied: six>=1.4.0 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jupyter-attention/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading sentry_sdk-1.40.3-py2.py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.8/257.8 kB 11.7 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Installing collected packages: appdirs, setproctitle, sentry-sdk, docker-pycreds, wandb
#   WARNING: The scripts wandb and wb are installed in '/home/jupyter-attention/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed appdirs-1.4.4 docker-pycreds-0.4.0 sentry-sdk-1.40.3 setproctitle-1.3.3 wandb-0.16.3

# %%
import wandb
import random

# %%
import os
import glob
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize
from PIL import Image
from TTS.encoder.models.i2v_encoder import I2VEncoder

# %%
torch.cuda.is_available()
# Out:
# True

# %%
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, image_paths, audio_embeddings, transforms=None):
        self.image_paths = image_paths
        self.audio_embeddings = audio_embeddings
        self.transforms = transforms

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = load_image(image_path)
        character = "Bill_Williamson" 
        audio_embedding = self.audio_embeddings.get(character)

        return image, audio_embedding

# %%
def load_image(image_path):
    image = Image.open(image_path).convert("RGB")
    transform = Compose([
        Resize(224),
        CenterCrop(224),
        ToTensor(),  # 이미지를 [0, 1] 범위의 텐서로 변환
    ])
    return transform(image)
    
def get_image_paths(root_dir, character_name):
    pattern = os.path.join(root_dir, "RedDeadRedemption2", character_name, "image", "*.jpg")
    print(pattern)
    return glob.glob(pattern)

def get_audio_embeddings(root_dir, character_name):
    audio_files = glob.glob(os.path.join(root_dir, "RedDeadRedemption2", character_name, "speaker_embedding", "*.pt"))
    if audio_files:
        return {character_name: audio_files}
    return {}
    
def encode_images(images):
    inputs = clip_processor(images=images, return_tensors="pt")
    outputs = clip_model.get_image_features(**inputs)
    return outputs

# %%
encoder = I2VEncoder()
encoder.load_checkpoint('/home/jupyter-attention/TTS/TTS/encoder/models/i2v_baseline.pt')

criterion = nn.CosineSimilarity(dim=1)
optimizer = optim.Adam(encoder.parameters(), lr=0.001)
root_dir = "/home/jupyter-attention/dataset_cleaned/"
character_name = "Bill_Williamson"
image_paths = get_image_paths(root_dir, character_name)
audio_embeddings = get_audio_embeddings(root_dir, character_name)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/image/*.jpg
# Using device: cuda

# %%
num_epochs = 100
batch_size = 16
selected_embeddings = {}
torch.cuda.empty_cache()
encoder.to(device)
# Out:
# I2VEncoder(
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 1024, kernel_size=(14, 14), stride=(14, 14), bias=False)
#       (position_embedding): Embedding(257, 1024)
#     )
#     (pre_layrnorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-23): 24 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (layer_norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#             (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           )
#           (layer_norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (projection): Linear(in_features=1024, out_features=512, bias=True)
# )

# %%
wandb.init(
    project="inu-attention",
    config={
    "learning_rate": 0.001,
    "epochs": num_epochs,
    "batch_size": batch_size,
    }
)

wandb.watch(encoder, criterion, log="all", log_freq=10)

for epoch in range(num_epochs):
    selected_embeddings = {}
    print(f"Epoch [{epoch+1}/{num_epochs}]")

    for character, files in audio_embeddings.items():
        if not files:
            continue
        selected_file = random.choice(files)
        # 오디오 임베딩을 CPU 또는 GPU로 로드
        selected_embeddings[character] = torch.load(selected_file, map_location=device)
        
        print(f"Character: {character}, Selected Audio Embedding File: {selected_file}")

    dataset = CustomDataset(image_paths, selected_embeddings)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    total_loss = 0
    for images, audio_embedding in data_loader:
        # 데이터를 현재 디바이스로 이동
        images = images.to(device)
        audio_embedding = audio_embedding.to(device)
        
        image_features = encoder.compute_embedding(images)
        loss = 1 - criterion(image_features, audio_embedding).mean()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    avg_loss = total_loss / len(data_loader)
    print(f"Loss: {avg_loss:.4f}\n")
    wandb.log({"epoch": epoch + 1, "loss": avg_loss})
wandb.finish()
# Out:
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/home/jupyter-attention/TTS/notebooks/wandb/run-20240213_055504-e1wyw9gq</code>
# Syncing run <strong><a href='https://wandb.ai/vmfh2003/inu-attention/runs/e1wyw9gq' target="_blank">sweet-rooster-1</a></strong> to <a href='https://wandb.ai/vmfh2003/inu-attention' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/vmfh2003/inu-attention' target="_blank">https://wandb.ai/vmfh2003/inu-attention</a>
#  View run at <a href='https://wandb.ai/vmfh2003/inu-attention/runs/e1wyw9gq' target="_blank">https://wandb.ai/vmfh2003/inu-attention/runs/e1wyw9gq</a>
# Epoch [1/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00331.pt
# Loss: 0.7344
#
# Epoch [2/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00352.pt
# Loss: 0.6914
#
# Epoch [3/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00322.pt
# Loss: 0.7891
#
# Epoch [4/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00409.pt
# Loss: 0.6308
#
# Epoch [5/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00028.pt
# Loss: 0.6992
#
# Epoch [6/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00439.pt
# Loss: 0.7539
#
# Epoch [7/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00363.pt
# Loss: 0.5547
#
# Epoch [8/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00314.pt
# Loss: 0.6836
#
# Epoch [9/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00193.pt
# Loss: 0.7461
#
# Epoch [10/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00348.pt
# Loss: 0.6328
#
# Epoch [11/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00269.pt
# Loss: 0.7751
#
# Epoch [12/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00265.pt
# Loss: 0.6367
#
# Epoch [13/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00261.pt
# Loss: 0.8107
#
# Epoch [14/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00436.pt
# Loss: 0.6992
#
# Epoch [15/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00126.pt
# Loss: 0.7227
#
# Epoch [16/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00120.pt
# Loss: 0.7461
#
# Epoch [17/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00149.pt
# Loss: 0.7559
#
# Epoch [18/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00153.pt
# Loss: 0.7638
#
# Epoch [19/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00090.pt
# Loss: 0.5820
#
# Epoch [20/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00218.pt
# Loss: 0.6836
#
# Epoch [21/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00436.pt
# Loss: 0.6914
#
# Epoch [22/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00279.pt
# Loss: 0.6680
#
# Epoch [23/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00075.pt
# Loss: 0.6406
#
# Epoch [24/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00435.pt
# Loss: 0.6172
#
# Epoch [25/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00314.pt
# Loss: 0.6758
#
# Epoch [26/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00336.pt
# Loss: 0.7227
#
# Epoch [27/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00077.pt
# Loss: 0.6641
#
# Epoch [28/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00303.pt
# Loss: 0.6016
#
# Epoch [29/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00459.pt
# Loss: 0.7500
#
# Epoch [30/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00107.pt
# Loss: 0.7188
#
# Epoch [31/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00156.pt
# Loss: 0.5742
#
# Epoch [32/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00380.pt
# Loss: 0.6602
#
# Epoch [33/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00190.pt
# Loss: 0.7539
#
# Epoch [34/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00060.pt
# Loss: 0.6719
#
# Epoch [35/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00313.pt
# Loss: 0.5703
#
# Epoch [36/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00370.pt
# Loss: 0.7344
#
# Epoch [37/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00042.pt
# Loss: 0.6406
#
# Epoch [38/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00209.pt
# Loss: 0.5547
#
# Epoch [39/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00223.pt
# Loss: 0.7656
#
# Epoch [40/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00080.pt
# Loss: 0.5664
#
# Epoch [41/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00288.pt
# Loss: 0.6016
#
# Epoch [42/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00225.pt
# Loss: 0.7266
#
# Epoch [43/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00140.pt
# Loss: 0.6836
#
# Epoch [44/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00260.pt
# Loss: 0.6953
#
# Epoch [45/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00221.pt
# Loss: 0.7109
#
# Epoch [46/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00272.pt
# Loss: 0.7773
#
# Epoch [47/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00003.pt
# Loss: 0.6641
#
# Epoch [48/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00168.pt
# Loss: 0.6875
#
# Epoch [49/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00420.pt
# Loss: 0.6758
#
# Epoch [50/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00202.pt
# Loss: 0.6484
#
# Epoch [51/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00366.pt
# Loss: 0.6406
#
# Epoch [52/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00225.pt
# Loss: 0.7266
#
# Epoch [53/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00230.pt
# Loss: 0.8164
#
# Epoch [54/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00438.pt
# Loss: 0.6641
#
# Epoch [55/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00295.pt
# Loss: 0.7266
#
# Epoch [56/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00307.pt
# Loss: 0.8086
#
# Epoch [57/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00050.pt
# Loss: 0.7148
#
# Epoch [58/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00349.pt
# Loss: 0.6484
#
# Epoch [59/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00369.pt
# Loss: 0.6602
#
# Epoch [60/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00187.pt
# Loss: 0.7188
#
# Epoch [61/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00110.pt
# Loss: 0.6953
#
# Epoch [62/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00148.pt
# Loss: 0.6133
#
# Epoch [63/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00349.pt
# Loss: 0.6484
#
# Epoch [64/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00164.pt
# Loss: 0.6172
#
# Epoch [65/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00287.pt
# Loss: 0.6875
#
# Epoch [66/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00372.pt
# Loss: 0.6484
#
# Epoch [67/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00105.pt
# Loss: 0.6953
#
# Epoch [68/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00175.pt
# Loss: 0.6133
#
# Epoch [69/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00219.pt
# Loss: 0.5078
#
# Epoch [70/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00206.pt
# Loss: 0.7305
#
# Epoch [71/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00308.pt
# Loss: 0.7070
#
# Epoch [72/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00449.pt
# Loss: 0.7031
#
# Epoch [73/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00319.pt
# Loss: 0.8164
#
# Epoch [74/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00419.pt
# Loss: 0.6055
#
# Epoch [75/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00268.pt
# Loss: 0.5938
#
# Epoch [76/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00372.pt
# Loss: 0.6445
#
# Epoch [77/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00331.pt
# Loss: 0.7227
#
# Epoch [78/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00180.pt
# Loss: 0.7109
#
# Epoch [79/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00315.pt
# Loss: 0.7109
#
# Epoch [80/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00261.pt
# Loss: 0.7891
#
# Epoch [81/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00450.pt
# Loss: 0.6484
#
# Epoch [82/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00082.pt
# Loss: 0.7812
#
# Epoch [83/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00214.pt
# Loss: 0.6914
#
# Epoch [84/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00286.pt
# Loss: 0.6094
#
# Epoch [85/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00410.pt
# Loss: 0.6211
#
# Epoch [86/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00011.pt
# Loss: 0.7852
#
# Epoch [87/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00126.pt
# Loss: 0.7070
#
# Epoch [88/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00313.pt
# Loss: 0.5625
#
# Epoch [89/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00192.pt
# Loss: 0.7227
#
# Epoch [90/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00090.pt
# Loss: 0.5898
#
# Epoch [91/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00092.pt
# Loss: 0.5625
#
# Epoch [92/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00460.pt
# Loss: 0.7656
#
# Epoch [93/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00209.pt
# Loss: 0.5508
#
# Epoch [94/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00238.pt
# Loss: 0.8086
#
# Epoch [95/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00083.pt
# Loss: 0.6406
#
# Epoch [96/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00255.pt
# Loss: 0.7109
#
# Epoch [97/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00314.pt
# Loss: 0.6758
#
# Epoch [98/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00224.pt
# Loss: 0.6562
#
# Epoch [99/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00069.pt
# Loss: 0.7773
#
# Epoch [100/100]
# Character: Bill_Williamson, Selected Audio Embedding File: /home/jupyter-attention/dataset_cleaned/RedDeadRedemption2/Bill_Williamson/speaker_embedding/Bill williamson_00290.pt
# Loss: 0.6758
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▆█▇▅▇█▇▇▅▄▆▃▃▅▆▇▃▅▇▅▄▅█▅▅▄▅▁▆▃▆▆▇▃▆▆▇█▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>loss</td><td>0.67578</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweet-rooster-1</strong> at: <a href='https://wandb.ai/vmfh2003/inu-attention/runs/e1wyw9gq' target="_blank">https://wandb.ai/vmfh2003/inu-attention/runs/e1wyw9gq</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240213_055504-e1wyw9gq/logs</code>

# %%
# 검증 데이터셋 준비
# 이 부분은 실제 검증 데이터셋에 맞게 수정해야 합니다.
val_image_paths = get_image_paths(val_root_dir, character_name)  # 검증 이미지 경로
val_audio_embeddings = get_audio_embeddings(val_root_dir, character_name)  # 검증 오디오 임베딩
val_dataset = CustomDataset(val_image_paths, val_audio_embeddings, transforms=transforms)
val_data_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 모델 평가
encoder.eval()  # 모델을 평가 모드로 설정
with torch.no_grad():
    total_val_loss = 0
    for images, audio_embedding in val_data_loader:
        image_features = encoder.compute_embedding(images)
        loss = 1 - criterion(image_features, audio_embedding).mean()
        total_val_loss += loss.item()
    
    avg_val_loss = total_val_loss / len(val_data_loader)
    print(f"Validation Loss: {avg_val_loss:.4f}")
encoder.train()  # 모델을 다시 학습 모드로 설정
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # 검증 데이터셋 준비
#       2 # 이 부분은 실제 검증 데이터셋에 맞게 수정해야 합니다.
# ----> 3 val_image_paths = get_image_paths(val_root_dir, character_name)  # 검증 이미지 경로
#       4 val_audio_embeddings = get_audio_embeddings(val_root_dir, character_name)  # 검증 오디오 임베딩
#       5 val_dataset = CustomDataset(val_image_paths, val_audio_embeddings, transforms=transforms)
#
# NameError: name 'val_root_dir' is not defined
